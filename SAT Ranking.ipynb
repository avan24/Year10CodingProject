# %%
import matplotlib.pyplot as plt
   
SAT = ['<1100','1100-1199','1200-1299','1300-1399','1400-1499','1500-1600']
Bar = [200,200,200,200,200,200]

#shrink the width of the graph
f = plt.figure()
f.set_figwidth(2.9)
plt.subplots(figsize=(4, 5)) 


plt.barh(SAT,Bar)
plt.title('Average SAT Score', fontweight="bold")
plt.xticks([]) #hides x-axis
plt.ylabel('SAT Score Range', fontsize='10')




Uni1 = ("Harvard, MIT, Stanford")
plt.text(10, 4.9, Uni1)

Uni2 = ("UCLA, UVA, ")
plt.text(10, 3.9, Uni2)

Uni3 = ("UF, OSU, CLEM")
plt.text(10, 2.9, Uni3)
        
Uni4 = ("USF, MSU,")
plt.text(10, 1.9, Uni4)

Uni5 = ("LSU, CU, ")
plt.text(10, 0.9, Uni5)

Uni6 = ("VSU")
plt.text(10, -0.1, Uni6)



plt.show()
